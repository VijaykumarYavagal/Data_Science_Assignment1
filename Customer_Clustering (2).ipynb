# %%
X = customers[["TotalSpend", "Region"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X = customers[["TotalSpend", "Region"]]
#
# NameError: name 'customers' is not defined

# %%
customers = pd.read_csv("D:\Data_Science_Assignment\datasets\Customers.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 customers = pd.read_csv("D:\Data_Science_Assignment\datasets\Customers.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

customers = pd.read_csv("D:\Data_Science_Assignment\datasets\Customers.csv")
transactions = pd.read_csv("D:\Data_Science_Assignment\datasets\Transactions.csv")

# %%
print(customers.columns)
# Out:
# Index(['CustomerID', 'CustomerName', 'Region', 'SignupDate'], dtype='object')

# %%
import pandas as pd

# Load the data
transactions = pd.read_csv("D:\Data_Science_Assignment\datasets\Transactions.csv")
customers = pd.read_csv("D:\Data_Science_Assignment\datasets\Customers.csv")

# Calculate total spending per customer
customer_total_spending = transactions.groupby("CustomerID")["TotalValue"].sum().reset_index()

# Merge the total spending with the customers DataFrame
customers = customers.merge(customer_total_spending, on="CustomerID", how="left")

# Now you have the "TotalValue" (total spending) in the customers DataFrame
X = customers[["TotalValue", "Region"]]

# %%
X = customers[["TotalValue", "Region"]]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15368\2546219378.py in ?()
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler = StandardScaler()
# ----> 3 X_scaled = scaler.fit_transform(X)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     914                 )
#     915
#     916         if y is None:
# ...

# %%
non_numeric_values = df['Region'][~df['Region'].astype(str).str.isnumeric()]
print(non_numeric_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 non_numeric_values = df['Region'][~df['Region'].astype(str).str.isnumeric()]
#       2 print(non_numeric_values)
#
# NameError: name 'df' is not defined

# %%
merged_df['TotalSpend'] = merged_df['TotalSpend'].fillna(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 merged_df['TotalSpend'] = merged_df['TotalSpend'].fillna(0)
#
# NameError: name 'merged_df' is not defined

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Load Data
customers_df = pd.read_csv("D:\Data_Science_Assignment\datasets\Customers.csv")")
transactions_df = pd.read_csv(""D:\Data_Science_Assignment\datasets\Transactions.csv")")

# Calculate Total Spending
customer_spending_df = transactions_df.groupby("CustomerID")["TotalValue"].sum().reset_index()
merged_df = customers_df.merge(customer_spending_df, on="CustomerID", how="left")

# Handle Missing Values (if necessary)
merged_df['TotalSpend'] = merged_df['TotalSpend'].fillna(0) 

# ... (Add feature engineering steps here if needed) ...

# Scale the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(merged_df[['TotalSpend', ...]]) # Include relevant features

# ... (Rest of the code for clustering and evaluation) ...
# Out:
#   Cell In[17], line 6
#     customers_df = pd.read_csv("D:\Data_Science_Assignment\datasets\Customers.csv")")
#                                                                                    ^
# SyntaxError: unterminated string literal (detected at line 6)

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Load Data
customers_df = pd.read_csv("D:\Data_Science_Assignment\datasets\Customers.csv")
transactions_df = pd.read_csv("D:\Data_Science_Assignment\datasets\Transactions.csv")

# Calculate Total Spending
customer_total_value_df = transactions_df.groupby("CustomerID")["TotalValue"].sum().reset_index()

# Merge DataFrames
merged_df = customers_df.merge(customer_total_value_df, on="CustomerID", how="left")

# Rename the column for clarity
merged_df.rename(columns={"TotalValue": "TotalSpend"}, inplace=True) 

# Handle Missing Values (if necessary)
merged_df['TotalSpend'] = merged_df['TotalSpend'].fillna(0) 

# ... (Add feature engineering steps here if needed) ...

# Scale the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(merged_df[['TotalSpend', 'Region']]) # Include relevant features

# ... (Rest of the code for clustering and evaluation) ...
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15368\1555501022.py in ?()
#      21 # ... (Add feature engineering steps here if needed) ...
#      22
#      23 # Scale the data
#      24 scaler = StandardScaler()
# ---> 25 scaled_data = scaler.fit_transform(merged_df[['TotalSpend', 'Region']]) # Include relevant features
#      26
#      27 # ... (Rest of the code for clustering and evaluation) ...
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# ...

# %%
df['Region'] = df['Region'].astype('category')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df['Region'] = df['Region'].astype('category')
#
# NameError: name 'df' is not defined

# %%
df = df.drop('Region', axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df = df.drop('Region', axis=1)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

Customers_df = pd.read_csv("D:\Data_Science_Assignment\datasets\Customers.csv")

df['Region'] = df['Region'].astype('category')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 5
#       1 import pandas as pd
#       3 Customers_df = pd.read_csv("D:\Data_Science_Assignment\datasets\Customers.csv")
# ----> 5 df['Region'] = df['Region'].astype('category')
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

customers_df = pd.read_csv("D:\Data_Science_Assignment\datasets\Customers.csv") 

customers_df['Region'] = customers_df['Region'].astype('category')

# %%
import numpy as np
customers_df['Region'] = customers_df['Region'].replace('South America', np.nan)

# %%
non_numeric_values = customers_df['Region'][customers_df['Region'].astype(str).str.isnumeric()]
print(non_numeric_values)
# Out:
# Series([], Name: Region, dtype: category
# Categories (3, object): ['Asia', 'Europe', 'North America'])

# %%
customers_df['Region'] = customers_df['Region'].astype('category')

# %%
merged_df['NumTransactions'] = transactions_df.groupby("CustomerID")["TotalValue"].count().reset_index()["TotalValue"]

# %%
import pandas as pd

# Convert the 'LastPurchaseDate' column to datetime
merged_df['LastPurchaseDate'] = pd.to_datetime(merged_df['LastPurchaseDate'], errors='coerce')

# Drop rows with NaT values if any
merged_df = merged_df.dropna(subset=['LastPurchaseDate'])

# Now you can safely find the max date
latest_date = merged_df['LastPurchaseDate'].max()

# Calculate the 'Recency' column
merged_df['Recency'] = (latest_date - merged_df['LastPurchaseDate']).dt.days

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(merged_df[['TotalSpend', 'AvgTransactionAmount', 'NumTransactions', 'Recency']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 4
#       1 from sklearn.preprocessing import StandardScaler
#       3 scaler = StandardScaler()
# ----> 4 scaled_data = scaler.fit_transform(merged_df[['TotalSpend', 'AvgTransactionAmount', 'NumTransactions', 'Recency']])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
# ...

# %%
# Check if 'AvgTransactionAmount' column exists
if 'AvgTransactionAmount' not in merged_df.columns:
    # Create the 'AvgTransactionAmount' column
    merged_df['AvgTransactionAmount'] = transactions_df.groupby('CustomerID')['TransactionAmount'].mean().reset_index()['TransactionAmount']

# Now you can scale the data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(merged_df[['TotalSpend', 'AvgTransactionAmount', 'NumTransactions', 'Recency']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 4
#       1 # Check if 'AvgTransactionAmount' column exists
#       2 if 'AvgTransactionAmount' not in merged_df.columns:
#       3     # Create the 'AvgTransactionAmount' column
# ----> 4     merged_df['AvgTransactionAmount'] = transactions_df.groupby('CustomerID')['TransactionAmount'].mean().reset_index()['TransactionAmount']
#       6 # Now you can scale the data
#       7 from sklearn.preprocessing import StandardScaler
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
# ...

# %%
# Check if 'TransactionAmount' column exists in transactions_df
if 'TransactionAmount' not in transactions_df.columns:
    # Create the 'TransactionAmount' column with some default values (e.g., 0)
    transactions_df['TransactionAmount'] = 0

# Now you can create the 'AvgTransactionAmount' column in merged_df
merged_df['AvgTransactionAmount'] = transactions_df.groupby('CustomerID')['TransactionAmount'].mean().reset_index()['TransactionAmount']

# Now you can scale the data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(merged_df[['TotalSpend', 'AvgTransactionAmount', 'NumTransactions', 'Recency']])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(merged_df[['TotalSpend', 'AvgTransactionAmount', 'NumTransactions', 'Recency']])

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

wcss = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS')
plt.show()

# %%
# Assuming you've determined the optimal number of clusters (e.g., k=3)
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(scaled_data)
cluster_labels = kmeans.labels_

# Add cluster labels to the DataFrame
merged_df['Cluster'] = cluster_labels

# %%
plt.figure(figsize=(8, 6))
plt.scatter(scaled_data[:, 0], scaled_data[:, 1], c=cluster_labels, cmap='viridis')
plt.title('K-Means Clustering')
plt.xlabel('Feature 1 (e.g., Scaled TotalSpend)') 
plt.ylabel('Feature 2 (e.g., Scaled NumTransactions)') 
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Now you can create the scatter plot
sns.scatterplot(x=customers["TotalSpend"], y=customers["Region"], hue=customers["Cluster"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TotalSpend'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 5
#       2 import matplotlib.pyplot as plt
# ...

# %%
# Check the length of scaled_data and customers DataFrame
print(len(scaled_data), len(customers))

# If the lengths don't match, you need to align them
if len(scaled_data) != len(customers):
    # Assuming you have a common identifier (e.g., 'CustomerID') to merge on
    customers = customers.merge(merged_df[['CustomerID', 'TotalSpend', 'AvgTransactionAmount', 'NumTransactions', 'Recency']], on='CustomerID', how='left')

# Perform K-Means clustering again with the aligned data
kmeans = KMeans(n_clusters=3, random_state
# Out:
#   Cell In[62], line 10
#     kmeans = KMeans(n_clusters=3, random_state
#                                               ^
# SyntaxError: incomplete input

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Impute missing values with the mean of each column
imputer = SimpleImputer(strategy='mean')
imputed_data = imputer.fit_transform(customers[['TotalSpend', 'AvgTransactionAmount', 'NumTransactions', 'Recency']])

# Scale the imputed data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(imputed_data)

# Perform K-Means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(scaled_data)
cluster_labels = kmeans.labels_

# Add cluster labels to the DataFrame
customers['Cluster'] = cluster_labels

# Now you can create the scatter plot
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x=customers["TotalSpend"], y=customers["Region"], hue=customers["Cluster"])
plt.show()
